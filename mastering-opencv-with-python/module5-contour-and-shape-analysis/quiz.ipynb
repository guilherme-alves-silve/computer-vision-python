# %%
# the exercise response is none of above, so the error is expected, because we have to pass a grayscale image

import cv2

img = cv2.imread('soccer.jpg', cv2.IMREAD_COLOR)
contours, hierarchy = cv2.findContours(img, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
print('Number of contours : ', len(contours))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[56], line 6
#       3 import cv2
#       5 img = cv2.imread('soccer.jpg', cv2.IMREAD_COLOR)
# ----> 6 contours, hierarchy = cv2.findContours(img, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#       7 print('Number of contours : ', len(contours))
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\contours_new.cpp:330: error: (-2:Unspecified error) in function 'class std::shared_ptr<struct ContourScanner_> __cdecl ContourScanner_::create(class cv::Mat,int,int,class cv::Point_<int>)'
# > Modes other than RETR_FLOODFILL and RETR_CCOMP support only CV_8UC1 images (expected: 'img.type() == CV_8UC1'), where
# >     'img.type()' is 16 (CV_8UC3)
# > must be equal to
# >     'CV_8UC1' is 0 (CV_8UC1)

# %%
import cv2

img = cv2.imread('soccer.jpg', cv2.IMREAD_COLOR)
imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

ret1, thresh1 = cv2.threshold(imgGray, 127, 255, cv2.THRESH_BINARY)
contours1, hierarchy1 = cv2.findContours( thresh1, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

ret2, thresh2 = cv2.threshold(imgGray, 127, 255, cv2.THRESH_BINARY_INV)
contours2, hierarchy2 = cv2.findContours( thresh2, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

print('Number of contours case 1 : ', len(contours1))
print('Number of contours case 2 : ', len(contours2))
# Out:
# Number of contours case 1 :  3
# Number of contours case 2 :  2

# %%
import matplotlib.pyplot as plt

image = cv2.imread("border.png", cv2.IMREAD_COLOR)
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
erosion_size = 45
erosion_shape = cv2.MORPH_ELLIPSE
element = cv2.getStructuringElement(erosion_shape, (2 * erosion_size + 1, 2 * erosion_size + 1),
                                   (erosion_size, erosion_size))
image_gray = cv2.erode(image_gray, element)
#plt.imshow(image_gray, cmap='gray')
ret, thresh = cv2.threshold(image_gray, 127, 255, cv2.THRESH_BINARY)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(image, contours, -1, (0,0,255), 3);
print("contours found:", len(contours))
plt.imshow(image)
# Out:
# contours found: 4
